# %%
import itertools
import sys, os

import numpy as np
import pandas as pd
from scipy.special import comb
from scipy import stats
import scipy.cluster.hierarchy as hac
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import statsmodels.api as sm

sns.set(rc={'figure.figsize':(15,8)})
sns.set_context('poster')
from sklearn.model_selection import train_test_split

# %%
import model.basic_model_lib

# %%
# %load_ext autoreload
# %autoreload 2
import CCPA_lib as cp

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.set_context('poster')
sns.set_style('white')

# %%
ppallete = 'RdYlGn'#'YlGn_d' #"BuGn_d"
porder = ['MED4',  'MIT9312','MIT0604', 'Natl2A', 'MIT9313']
ppallete = [ '#62A586', '#face6e','#f79934', '#7A9BC8', '#F47681', ]
psizes = [150,120,200,120,350]
pmarkers = ['o', 's', '^', 'D', '*']

# #ffd7a1
    
pedge = 'green'
apallete = "spring"
aorder = ['DE', 'DE1', '1A3', 'ATCC', 'BS11']
amarkers = ['P', 'X', 'h', '<','>']
apallete = ['#6dad36', '#c7e89f', '#f5c4e1', '#d5579d', '#8a0850']

aedge='orange'
epallete = ['#6cf0ba', '#d13f75', '#eeb7cb', '#b9d2d8', '#407f90']
#sns.diverging_palette(355, 217, s=74, l=50, n=4) #'Paired' # 'BrBG'# "coolwarm"
eorder = ['e1','e3', 'e4', 'e5', 'e6']
#aedge='orange'

# %%
PRO_COLOR = 'MediumSeaGreen'
PRO_FL_COLOR = 'DarkGreen'
PRO_FCM_COLOR = 'MediumSpringGreen'

ALT_COLOR = 'Gold'
ALT_FCM_COLOR = 'PaleGoldenrod'
N_COLOR = 'royalblue'
ON_COLOR = 'PowderBlue'
C_COLOR = 'FireBrick'
OC_COLOR = 'LightCoral'

mcolors = {
    'b_n_p' : PRO_COLOR, 
    'b_c_p': PRO_COLOR, 
    'b_n_a': ALT_COLOR , 
    'b_c_a' : ALT_COLOR, 
    'x_p': PRO_COLOR, 
    'x_a': ALT_COLOR, 
    'n' : N_COLOR, 
    'c': C_COLOR, 
    'on': ON_COLOR, 
    'oc':OC_COLOR,
    'q_n_p' :PRO_COLOR, 
    'q_c_p': PRO_COLOR, 
}

# %%
from sympy import *

# %%
df = pd.read_pickle('CCPA.pkl.gz')
df.loc[df.PRO == 'C9B', 'PRO'] = 'MIT0604'

# %%
fl2cell_model, compdf = cp.gen_FL2cells_model()
df['cells'] = cp.compute_FL2cells(df['FL'], fl2cell_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FCM   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     776.5
# Date:                Sun, 31 May 2020   Prob (F-statistic):           2.49e-90
# Time:                        12:11:04   Log-Likelihood:                -6527.3
# No. Observations:                 347   AIC:                         1.306e+04
# Df Residuals:                     345   BIC:                         1.307e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.769e+05   3.27e+06     -0.177      0.860      -7e+06    5.85e+06
# FL          3.521e+07   1.26e+06     27.866      0.000    3.27e+07    3.77e+07
# ==============================================================================
# Omnibus:                       25.759   Durbin-Watson:                   1.544
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.283
# Skew:                           0.373   Prob(JB):                     3.64e-13
# Kurtosis:                       4.845   Cond. No.                         4.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\wosnat\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df.head()
# Out:
#         day experiment sample     FL   PRO  ALT     culture  FL_orig  \
# 0  0.000000         e1     1A  0.133  MED4  1A3  Co_Culture    0.133
# 1  0.715972         e1     1A  0.159  MED4  1A3  Co_Culture    0.159
# 2  1.925694         e1     1A  0.155  MED4  1A3  Co_Culture    0.155
# 3  2.831250         e1     1A  0.180  MED4  1A3  Co_Culture    0.180
# 4  6.674306         e1     1A  0.632  MED4  1A3  Co_Culture    0.632
#
#       logFL  cumsumFL  cumsumlogFL  zscoreFL  diffFL  difflogFL   diffday  \
# 0 -2.017406     0.133    -2.017406 -0.588889     NaN        NaN       NaN
# 1 -1.838851     0.292    -3.856257 -0.575917   0.026   0.178555  0.715972
# 2 -1.864330     0.447    -5.720587 -0.577913  -0.004  -0.025479  1.209722
# 3 -1.714798     0.627    -7.435386 -0.565440   0.025   0.149532  0.905556
# 4 -0.458866     1.259    -7.894252 -0.339936   0.452   1.255933  3.843056
#
#      rateFL  ratelogFL experiment_sample         cells
# 0       NaN        NaN            e1, 1A  4.105691e+06
# 1  0.036314   0.249388            e1, 1A  5.021082e+06
# 2 -0.003307  -0.021062            e1, 1A  4.880252e+06
# 3  0.027607   0.165127            e1, 1A  5.760436e+06
# 4  0.117615   0.326806            e1, 1A  2.167415e+07

# %%
fcmdflist=list()
for i in os.listdir('fcmfiles'):
    if i.endswith('.csv'):
        d = pd.read_csv(os.path.join('fcmfiles', i))
        n = os.path.splitext(i)[0]
        _, experiment, day = n.split('_')
        d['experiment'] = experiment
        d['day'] = day.replace('Days','')
        fcmdflist.append(d)
fcmdf = pd.concat(fcmdflist)
fcmdf.loc[fcmdf.PRO == 'C9B', 'PRO'] = 'MIT0604'
fcmdf['day'] = pd.to_numeric(fcmdf['day'])

# %%
df1 = df.loc[df.experiment.isin(['e1']) & df.PRO.isin(['MED4']) & df.culture.isin(['Axenic'])]
fcmdf1 = fcmdf.loc[fcmdf.experiment.isin(['exp1']) & 
                   fcmdf.PRO.isin(['MED4']) & 
                  fcmdf.ALT.isna()]

compdf1 = compdf.loc[compdf.MODE.isin(['lowN']) & 
                   compdf.PRO.isin(['MED4']) ]
compdf1.rename(columns={'FCM': 'PRO.1'}, inplace=True)
reffcmdf1 = pd.concat([fcmdf1.loc[:,['day', 'PRO.1']], compdf1.loc[:,['day', 'PRO.1']], ])
# Out:
# C:\Users\wosnat\Anaconda3\lib\site-packages\pandas\core\frame.py:4218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %% [raw]
# dfw = df.loc[(df.experiment.isin(['e1', 'e3', 'e4','e5', 'e6']))]

# %%
import model.basic_model_lib

# %%
m = model.basic_model_lib.ModelProALT()

# %% [raw]
# init_printing()
# for i in m.intermediate_variables.values():
#     display(i.symbol, i.formula)
#     print()
#
# for i in m.variables.values():
#     display(i.symbol, i.formula)
#     print()

# %%
m.print_param_values()
# Out:
# gamma_n_p 0.04
# gamma_c_p 0.04
# gamma_n_a 0.04
# gamma_c_a 0.04
# gamma_refractory_n_p 0.1
# gamma_refractory_c_p 0.1
# gamma_refractory_n_a 0.1
# gamma_refractory_c_a 0.1
# excretion_n_p 0.01
# excretion_c_p 0.01
# excretion_n_a 0.01
# excretion_c_a 0.01
# v_n_max_p 1.9e-09
# v_c_max_p 8e-09
# v_in_max_a 1.4582177199759883e-09
# v_n_max_a 1.4582177199759882e-08
# v_c_max_a 6.139864084109425e-08
# mu_inf_p 0.86
# mu_inf_a 5.16
# k_n_p 0.11008885160313818
# k_c_p 0.11008885160313818
# k_n_a 0.2502723352076287
# k_in_a 0.02502723352076287
# k_c_a 0.2502723352076287
# q_n_min_p 7e-10
# q_c_min_p 3e-11
# q_n_min_a 1.4658725248598342e-08
# q_c_min_a 6.282310820827862e-10
# q_n_max_p 1.5e-09
# q_c_max_p 6e-09
# q_n_max_a 3.1411554104139307e-08
# q_c_max_a 1.2564621641655723e-07
# mortality_p 0.1
# mortality_a 0.1
# r0_p 0.18
# r0_a 0.18
# b_p 0.01
# b_a 0.01
# delta_t 1.1574074074074073e-05

# %%
m = model.basic_model_lib.ModelProALT()
m.disable_organism('ALT')
m.override_initial_values({
    'b_n_a': 0,
    'b_c_a': 0,
    'x_a': 0,
})
#m.override_param_values({i : k for i, k in zip(param_names, param_values)})
reference_days = reffcmdf1['day'].unique().tolist()
#max_day = int(ref_df['day'].max()) + 1
max_day = 140
m.set_referece_times(reference_days)
res, ref_res = m.simulate(num_iterations=max_day*3600*24, collect_every=3600*6)
# Out:
# .................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
res[0]
# Out:
# {'b_n_p': 0.7,
#  'b_c_p': 0.03,
#  'b_n_a': 0.0,
#  'b_c_a': 0.0,
#  'x_p': 1000000000.0,
#  'x_a': 0,
#  'n': 100,
#  'c': 2000,
#  'on': 20,
#  'oc': 60,
#  'on_refractory': 0,
#  'oc_refractory': 0,
#  'day': 0.0}

# %%
res_df = pd.DataFrame(res)

# %%
df1 = df.loc[df.experiment.isin(['e1']) & df.PRO.isin(['MED4']) & df.culture.isin(['Axenic'])]
fcmdf1 = fcmdf.loc[fcmdf.experiment.isin(['exp1']) & 
                   fcmdf.PRO.isin(['MED4']) & 
                  fcmdf.ALT.isna()]

compdf1 = compdf.loc[compdf.MODE.isin(['lowN']) & 
                   compdf.PRO.isin(['MED4']) ]
compdf1.rename(columns={'FCM': 'PRO.1'}, inplace=True)
reffcmdf1 = pd.concat([fcmdf1.loc[:,['day', 'PRO.1']], compdf1.loc[:,['day', 'PRO.1']], ])


model.basic_model_lib.display_simulation_results(
    res_df, m, 'PRO only', 
    reference_FL_df=df1, reference_FCM_df=reffcmdf1,
    pro_only=True)
# Out:
# C:\Users\wosnat\Anaconda3\lib\site-packages\pandas\core\frame.py:4218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
res_df.loc[res_df.oc <0].head()
# Out:
# Empty DataFrame
# Columns: [b_n_p, b_c_p, b_n_a, b_c_a, x_p, x_a, n, c, on, oc, on_refractory, oc_refractory, day, q_n_p, q_c_p]
# Index: []

# %%
res_df.loc[res_df.n <0].head()
# Out:
# Empty DataFrame
# Columns: [b_n_p, b_c_p, b_n_a, b_c_a, x_p, x_a, n, c, on, oc, on_refractory, oc_refractory, day, q_n_p, q_c_p]
# Index: []

# %%
res_df.tail()
# Out:
#         b_n_p     b_c_p  b_n_a  b_c_a            x_p  x_a        n  \
# 555  0.000138  0.001044    0.0    0.0  197930.488978    0  0.00016
# 556  0.000134  0.001017    0.0    0.0  192754.216373    0  0.00016
# 557  0.000130  0.000990    0.0    0.0  187713.313505    0  0.00016
# 558  0.000127  0.000964    0.0    0.0  182804.240188    0  0.00016
# 559  0.000124  0.000939    0.0    0.0  178023.548819    0  0.00016
#
#               c          on          oc  on_refractory  oc_refractory     day  \
# 555  1406.62281  110.629732  594.065531      10.069970      59.340615  138.75
# 556  1406.62281  110.629735  594.065556      10.069971      59.340617  139.00
# 557  1406.62281  110.629738  594.065580      10.069971      59.340620  139.25
# 558  1406.62281  110.629741  594.065603      10.069971      59.340623  139.50
# 559  1406.62281  110.629744  594.065626      10.069972      59.340625  139.75
#
#             q_n_p         q_c_p
# 555  6.951501e-10  5.275764e-09
# 556  6.951501e-10  5.275764e-09
# 557  6.951501e-10  5.275764e-09
# 558  6.951501e-10  5.275764e-09
# 559  6.951501e-10  5.275764e-09

# %%
param_values = [1.9e-09, 0.86, 0.11, #7e-10,1.5e-09
               ]
param_names = [
'v_n_max_p',
'mu_inf_p', 
'k_n_p' ,
#'q_n_min_p' ,
#'q_n_max_p' ,
]

from scipy.optimize import differential_evolution
ref_df = reffcmdf1
ref_df.rename(columns={'PRO.1': 'VALUE'}, inplace=True)
print(ref_df.head())
opt_func = lambda x : model.basic_model_lib.model_optimize_PRO(x, ref_df, param_names)
def compute_bounds(i):
    if i < 0.1:
        return (i/10, i*10)
        #return (0, 0.2)
    else:
        return (i/10, i*2)
    
bounds = [compute_bounds(i) for i in param_values]
result = differential_evolution(opt_func, bounds, disp=True)
# Out:
# 0     day        VALUE
# 87  100.0   710.900474
# 88  100.0  1184.834123
# 89  100.0  1184.834123
# 87  140.0   580.000000
# 88  140.0   240.000000
# .56.678101977944145
# .53.77379503846303
# .52.52195855854729
# .55.57924051420074
# .54.33640906601929
# .53.18960879198702
# .63.05342130891367
# .34.651726458033465
# .55.029593436305916
# .54.785209760290414
# .58.82674424687476
# .55.70316490754357
# .56.00527513480121
# .56.767269232138176
# .56.794607899278226
# .56.47830301550846
# .54.041831419731224
# .56.27601770859595
# .56.94885470218652
# .55.468296191685155
# .57.14996144962465
# .56.86842171041915
# .56.59724888760086
# .52.98590103484127
# .52.69293646968021
# .52.567914288875194
# .56.89943756976043
# .56.17746620330966
# .59.05964364690996
# .55.24695296785668
# .55.26812587700796
# .55.53098535247509
# .56.10262047027077
# .41.25198676361174
# .54.58606916262049
# .55.396091631133494
# .56.21536490327334
# .54.12876958310726
# .52.685329655624315
# .52.49620156238418
# .56.32614922710059
# .70.41959596825109
# .55.77583164002796
# .53.44529429161887
# .57.34896990995461
# .53.53810753273693
# .57.16187157297936
# .55.827518340812965
# .41.17525854431643
# .55.300207227678854
# .56.879193425423665
# .66.2405852980299
# .60.030495951514986
# .52.88083207507997
# .54.78648737756635
# .52.543222415496864
# .58.864589611053866
# .56.71228827811449
# .56.890407049370964
# .56.797163586715236
# .56.25863677891235
# .55.8852900930955
# .55.89308215714423

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-df7c5ae370ce> in <module>
#      22
#      23 bounds = [compute_bounds(i) for i in param_values]
# ---> 24 result = differential_evolution(opt_func, bounds, disp=True)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers)
#     274                                      updating=updating,
#     275                                      workers=workers) as solver:
# --> 276         ret = solver.solve()
#     277
#     278     return ret
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in solve(self)
#     693             # evolve the population by a generation
#     694             try:
# --> 695                 next(self)
#     696             except StopIteration:
#     697                 warning_flag = True
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in __next__(self)
#     862
#     863                 # determine the energy of the objective function
# --> 864                 energy = self.func(parameters)
#     865                 self._nfev += 1
#     866
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in __call__(self, x)
#    1026
#    1027     def __call__(self, x):
# -> 1028         return self.f(x, *self.args)
#
# <ipython-input-26-df7c5ae370ce> in <lambda>(x)
#      13 ref_df.rename(columns={'PRO.1': 'VALUE'}, inplace=True)
#      14 print(ref_df.head())
# ---> 15 opt_func = lambda x : model.basic_model_lib.model_optimize_PRO(x, ref_df, param_names)
#      16 def compute_bounds(i):
#      17     if i < 0.1:
#
# ~\Documents\GitHub\ccpa\model\basic_model_lib.py in model_optimize_PRO(param_values, ref_df, param_names)
#     657     d = DisplayModel(res_df, model, model_name, reference_FL_df, reference_FCM_df, pro_only, max_day,
#     658                      ref_pro_col, ref_alt_col)
# --> 659
#     660     sns.set(context='paper', style='white')
#     661     # cells
#
# ~\Documents\GitHub\ccpa\model\basic_model_lib.py in simulate(self, num_iterations, collect_every)
#     462         assert nutrient in ['n', 'c', None]
#     463         self._disable_nutrient  =  nutrient
# --> 464         # override mu formula to take into account only one nutrient
#     465         s = lambda x : self.symbol(x)
#     466         n = 'n' if self._disable_nutrient == 'c' else 'c'
#
# ~\Documents\GitHub\ccpa\model\basic_model_lib.py in evaluate(self)
#     429             i.run_lambdify(param_values, var_symbols, self.intermediate_variables, self.intermediate_evaluation_order)
#     430
# --> 431     # dxa_dt= (mu- m_star)*x;
#     432     #i = delta_b_c_a_excretion.subs({b_c_a'): 5, b_c_p'): 3})
#     433
#
# ~\Documents\GitHub\ccpa\model\basic_model_lib.py in evaluate(self, variables_values)
#      68         var_list_for_lambda = [v[1] for v in variables_list]
#      69
# ---> 70         self.lambdafun = lambdify(var_list_for_lambda, subs_expr2)
#      71
#      72     def evaluate(self, variables_values):
#
# <lambdifygenerated-8957> in _lambdifygenerated(B_N_P, B_C_P, X_P, N, C, ON, OC, ON_refractory, OC_refractory)
#       1 def _lambdifygenerated(B_N_P, B_C_P, X_P, N, C, ON, OC, ON_refractory, OC_refractory):
# ----> 2     return (-1.15740740740741e-5*B_C_P*(0.180878405093777 - 0.000878405093776884*amax((3.0e-11*X_P/B_C_P,7.0e-10*X_P/B_N_P))) + 0.999998726851852*B_C_P + 1.55096470004343e-5*C*X_P*(-B_C_P/X_P + 6.0e-9)/(C + 0.110088851603138))
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2619     """
#    2620     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
# -> 2621                           keepdims=keepdims, initial=initial, where=where)
#    2622
#    2623
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:
