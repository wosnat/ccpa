# %%
import itertools
import sys, os

import numpy as np
import pandas as pd
from scipy.special import comb
from scipy import stats
import scipy.cluster.hierarchy as hac
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import statsmodels.api as sm

sns.set(rc={'figure.figsize':(15,8)})
sns.set_context('poster')
from sklearn.model_selection import train_test_split

# %%
import model.basic_model_lib

# %%
# %load_ext autoreload
# %autoreload 2
import CCPA_lib as cp

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.set_context('poster')
sns.set_style('white')

# %%
ppallete = 'RdYlGn'#'YlGn_d' #"BuGn_d"
porder = ['MED4',  'MIT9312','MIT0604', 'Natl2A', 'MIT9313']
ppallete = [ '#62A586', '#face6e','#f79934', '#7A9BC8', '#F47681', ]
psizes = [150,120,200,120,350]
pmarkers = ['o', 's', '^', 'D', '*']

# #ffd7a1
    
pedge = 'green'
apallete = "spring"
aorder = ['DE', 'DE1', '1A3', 'ATCC', 'BS11']
amarkers = ['P', 'X', 'h', '<','>']
apallete = ['#6dad36', '#c7e89f', '#f5c4e1', '#d5579d', '#8a0850']

aedge='orange'
epallete = ['#6cf0ba', '#d13f75', '#eeb7cb', '#b9d2d8', '#407f90']
#sns.diverging_palette(355, 217, s=74, l=50, n=4) #'Paired' # 'BrBG'# "coolwarm"
eorder = ['e1','e3', 'e4', 'e5', 'e6']
#aedge='orange'

# %%
from sympy import *

# %%
df = pd.read_pickle('CCPA.pkl.gz')
df.loc[df.PRO == 'C9B', 'PRO'] = 'MIT0604'

# %%
fl2cell_model, compdf = cp.gen_FL2cells_model()
df['cells'] = cp.compute_FL2cells(df['FL'], fl2cell_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FCM   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     776.5
# Date:                Sun, 31 May 2020   Prob (F-statistic):           2.49e-90
# Time:                        12:14:56   Log-Likelihood:                -6527.3
# No. Observations:                 347   AIC:                         1.306e+04
# Df Residuals:                     345   BIC:                         1.307e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.769e+05   3.27e+06     -0.177      0.860      -7e+06    5.85e+06
# FL          3.521e+07   1.26e+06     27.866      0.000    3.27e+07    3.77e+07
# ==============================================================================
# Omnibus:                       25.759   Durbin-Watson:                   1.544
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.283
# Skew:                           0.373   Prob(JB):                     3.64e-13
# Kurtosis:                       4.845   Cond. No.                         4.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\wosnat\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df.head()
# Out:
#         day experiment sample     FL   PRO  ALT     culture  FL_orig  \
# 0  0.000000         e1     1A  0.133  MED4  1A3  Co_Culture    0.133
# 1  0.715972         e1     1A  0.159  MED4  1A3  Co_Culture    0.159
# 2  1.925694         e1     1A  0.155  MED4  1A3  Co_Culture    0.155
# 3  2.831250         e1     1A  0.180  MED4  1A3  Co_Culture    0.180
# 4  6.674306         e1     1A  0.632  MED4  1A3  Co_Culture    0.632
#
#       logFL  cumsumFL  cumsumlogFL  zscoreFL  diffFL  difflogFL   diffday  \
# 0 -2.017406     0.133    -2.017406 -0.588889     NaN        NaN       NaN
# 1 -1.838851     0.292    -3.856257 -0.575917   0.026   0.178555  0.715972
# 2 -1.864330     0.447    -5.720587 -0.577913  -0.004  -0.025479  1.209722
# 3 -1.714798     0.627    -7.435386 -0.565440   0.025   0.149532  0.905556
# 4 -0.458866     1.259    -7.894252 -0.339936   0.452   1.255933  3.843056
#
#      rateFL  ratelogFL experiment_sample         cells
# 0       NaN        NaN            e1, 1A  4.105691e+06
# 1  0.036314   0.249388            e1, 1A  5.021082e+06
# 2 -0.003307  -0.021062            e1, 1A  4.880252e+06
# 3  0.027607   0.165127            e1, 1A  5.760436e+06
# 4  0.117615   0.326806            e1, 1A  2.167415e+07

# %%
fcmdflist=list()
for i in os.listdir('fcmfiles'):
    if i.endswith('.csv'):
        d = pd.read_csv(os.path.join('fcmfiles', i))
        n = os.path.splitext(i)[0]
        _, experiment, day = n.split('_')
        d['experiment'] = experiment
        d['day'] = day.replace('Days','')
        fcmdflist.append(d)
fcmdf = pd.concat(fcmdflist)
fcmdf.loc[fcmdf.PRO == 'C9B', 'PRO'] = 'MIT0604'
fcmdf['day'] = pd.to_numeric(fcmdf['day'])

# %% [raw]
# dfw = df.loc[(df.experiment.isin(['e1', 'e3', 'e4','e5', 'e6']))]

# %%
import model.basic_model_lib

# %%
m = model.basic_model_lib.ModelProALT()

# %%
m.print_initial_values()
# Out:
# b_n_p 0.7
# b_c_p 0.03
# b_n_a 146.5872524859834
# b_c_a 6.2823108208278615
# x_p 1000000000.0
# x_a 10000000000.0
# n 100
# c 2000
# on 20
# oc 60
# on_refractory 0
# oc_refractory 0

# %%
init_printing()
for i in m.intermediate_variables.values():
    display(i.symbol, i.formula)
    print()

for i in m.variables.values():
    display(i.symbol, i.formula)
    print()
# Out:
# Q_N__P
# B_N__P
# ──────
#  X__P
# Q_C__P
# B_C__P
# ──────
#  X__P
# Q_N__A
# B_N__A
# ──────
#  X__A
# Q_C__A
# B_C__A
# ──────
#  X__A
# μ__P
# μ_inf__P⋅(1 - Max(Q_C_min^P/Q_C^P, Q_N_min^P/Q_N^P))
# μ__A
# μ_inf__A⋅(1 - Max(Q_C_min^A/Q_C^A, Q_N_min^A/Q_N^A))
# B_N_uptake__P
# N⋅V_N_max__P⋅X__P⋅(-Q_N__P + Q_N_max__P)
# ────────────────────────────────────────
#  (N + k_N__P)⋅(Q_N_max__P - Q_N_min__P)
# B_N_mortality__P
# B_N__P⋅mortality__P
# B_N_excretion__P
# B_N__P⋅Excretion_N__P
# B_ON_uptake__A
# ON⋅V_N_max__A⋅X__A⋅(-Q_N__A + Q_N_max__A)
# ─────────────────────────────────────────
#  (ON + k_ON__A)⋅(Q_N_max__A - Q_N_min__A)
# B_N_uptake__A
# N⋅V_IN_max__A⋅X__A⋅(-Q_N__A + Q_N_max__A)
# ─────────────────────────────────────────
#   (N + k_N__A)⋅(Q_N_max__A - Q_N_min__A)
# B_N_mortality__A
# B_N__A⋅mortality__A
# B_N_excretion__A
# B_N__A⋅Excretion_N__A
# B_C_uptake__P
# C⋅V_C_max__P⋅X__P⋅(-Q_C__P + Q_C_max__P)
# ────────────────────────────────────────
#  (C + k_C__P)⋅(Q_C_max__P - Q_C_min__P)
# B_C_mortality__P
# B_C__P⋅mortality__P
# B_C_excretion__P
# B_C__P⋅Excretion_C__P
# B_C_respiration__P
# B_C__P⋅(b__P⋅μ__P + r_0__P)
# B_OC_uptake__A
# OC⋅V_C_max__A⋅X__A⋅(-Q_C__A + Q_C_max__A)
# ─────────────────────────────────────────
#  (OC + k_OC__A)⋅(Q_C_max__A - Q_C_min__A)
# B_C_mortality__A
# B_C__A⋅mortality__A
# B_C_excretion__A
# B_C__A⋅Excretion_C__A
# B_C_respiration__A
# B_C__A⋅(b__A⋅μ__A + r_0__A)
# B_N__P
# B_N__P + Δₜ⋅(-B_N_excretion__P - B_N_mortality__P + B_N_uptake__P)
# B_C__P
# B_C__P + Δₜ⋅(-B_C_excretion__P - B_C_mortality__P - B_C_respiration__P + B_C_u
# ptake__P)
# B_N__A
# B_N__A + Δₜ⋅(-B_N_excretion__A - B_N_mortality__A + B_N_uptake__A + B_ON_uptak
# e__A)
# B_C__A
# B_C__A + Δₜ⋅(-B_C_excretion__A - B_C_mortality__A - B_C_respiration__A + B_OC_
# uptake__A)
# X__P
# Δₜ⋅(-X__P⋅mortality__P + X__P⋅μ__P) + X__P
# X__A
# Δₜ⋅(-X__A⋅mortality__A + X__A⋅μ__A) + X__A
# N
# Δₜ⋅(B_N_excretion__A + B_N_mortality__A⋅γ_N__A + B_N_mortality__P⋅γ_N__P - B_N
# _uptake__A - B_N_uptake__P) + N
# C
# C + Δₜ⋅(B_C_excretion__A + B_C_mortality__A⋅γ_C__A + B_C_mortality__P⋅γ_C__P +
#  B_C_respiration__A + B_C_respiration__P - B_C_uptake__P)
# ON
# Δₜ⋅(B_N_excretion__P⋅(1 - γ_refractory_N__P) + B_N_mortality__A⋅(1 - γ_N__A)⋅(
# 1 - γ_refractory_N__A) + B_N_mortality__P⋅(1 - γ_N__P)⋅(1 - γ_refractory_N__P)
#  - B_ON_uptake__A) + ON
# OC
# Δₜ⋅(B_C_excretion__P⋅(1 - γ_refractory_C__P) + B_C_mortality__A⋅(1 - γ_C__A)⋅(
# 1 - γ_refractory_C__A) + B_C_mortality__P⋅(1 - γ_C__P)⋅(1 - γ_refractory_C__P)
#  - B_OC_uptake__A) + OC
# ON_refractory
# Δₜ⋅(B_N_excretion__P⋅γ_refractory_N__P + B_N_mortality__A⋅γ_refractory_N__A⋅(1
#  - γ_N__A) + B_N_mortality__P⋅γ_refractory_N__P⋅(1 - γ_N__P)) + ON_refractory
# OC_refractory
# Δₜ⋅(B_C_excretion__P⋅γ_refractory_C__P + B_C_mortality__A⋅γ_refractory_C__A⋅(1
#  - γ_C__A) + B_C_mortality__P⋅γ_refractory_C__P⋅(1 - γ_C__P)) + OC_refractory

# %%
m.print_param_values()
# Out:
# gamma_n_p 0.04
# gamma_c_p 0.04
# gamma_n_a 0.04
# gamma_c_a 0.04
# gamma_refractory_n_p 0.1
# gamma_refractory_c_p 0.1
# gamma_refractory_n_a 0.1
# gamma_refractory_c_a 0.1
# excretion_n_p 0.01
# excretion_c_p 0.01
# excretion_n_a 0.01
# excretion_c_a 0.01
# v_n_max_p 1.9e-09
# v_c_max_p 8e-09
# v_in_max_a 1.4582177199759883e-09
# v_n_max_a 1.4582177199759882e-08
# v_c_max_a 6.139864084109425e-08
# mu_inf_p 0.86
# mu_inf_a 5.16
# k_n_p 0.11008885160313818
# k_c_p 0.11008885160313818
# k_n_a 0.2502723352076287
# k_in_a 0.02502723352076287
# k_c_a 0.2502723352076287
# q_n_min_p 7e-10
# q_c_min_p 3e-11
# q_n_min_a 1.4658725248598342e-08
# q_c_min_a 6.282310820827862e-10
# q_n_max_p 1.5e-09
# q_c_max_p 6e-09
# q_n_max_a 3.1411554104139307e-08
# q_c_max_a 1.2564621641655723e-07
# mortality_p 0.1
# mortality_a 0.1
# r0_p 0.18
# r0_a 0.18
# b_p 0.01
# b_a 0.01
# delta_t 1.1574074074074073e-05

# %%
m = model.basic_model_lib.ModelProALT()
#m.disable_organism('ALT')
#m.override_initial_values({
#    'b_n_a': 0,
#    'b_c_a': 0,
#    'x_a': 0,
#})
#m.override_param_values({i : k for i, k in zip(param_names, param_values)})
# disable ALT consumption of N
m.override_param_values({'v_in_max_a' : 0})
#reference_days = ref_df['day'].unique().tolist()
#max_day = int(ref_df['day'].max()) + 1
max_day = 140
#m.set_referece_times(reference_days)
res, ref_res = m.simulate(num_iterations=max_day*3600*24, collect_every=3600*6)
# Out:
# .................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
res_df = pd.DataFrame(res)

# %%
df1 = df.loc[df.experiment.isin(['e1']) & df.PRO.isin(['MED4']) & df.culture.isin(['Co_Culture']) &
            df.ALT.isin(['1A3'])]
fcmdf1 = fcmdf.loc[fcmdf.experiment.isin(['exp1']) & 
                   fcmdf.PRO.isin(['MED4']) & 
                   fcmdf.ALT.isin(['1A3'])]
compdf1 = compdf.loc[compdf.MODE.isin(['1A3']) & 
                   compdf.PRO.isin(['MED4']) ]
compdf1.rename(columns={'FCM': 'PRO.1'}, inplace=True)
reffcmdf1 = pd.concat([fcmdf1.loc[:,['day', 'PRO.1', 'ALT.1']], compdf1.loc[:,['day', 'PRO.1']], ])


model.basic_model_lib.display_simulation_results(
    res_df, m, 'co-culture', 
    reference_FL_df=df1, reference_FCM_df=reffcmdf1)
# Out:
# C:\Users\wosnat\Anaconda3\lib\site-packages\pandas\core\frame.py:4218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
# C:\Users\wosnat\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
fcmdf1
