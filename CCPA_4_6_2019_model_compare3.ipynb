# %%
import itertools
import sys, os

import numpy as np
import pandas as pd
from scipy.special import comb
from scipy import stats
import scipy.cluster.hierarchy as hac
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
sns.set(rc={'figure.figsize':(15,8)})
sns.set_context('poster')
from sklearn.model_selection import train_test_split

# %%
#import tsfresh

# %%
# %load_ext autoreload
# %autoreload 2
import CCPA_lib as cp

# %%
sns.set_context('poster')

# %%
ppallete = "BuGn"
porder = ['MIT9313', 'Natl2A', 'C9B', 'MIT9312', 'MED4']
pedge = 'green'
apallete = "Oranges"
aorder = ['1A3', 'DE', 'DE1', 'ATCC', 'BS11']
aedge='orange'

# %% [raw]
# df = cp.load_experiment_csvs()
# df = cp.update_calculated_fields(df)

# %% [raw]
# df.head()

# %% [raw]
# df.to_pickle('CCPA.pkl.gz')

# %%
df = pd.read_pickle('CCPA.pkl.gz')

# %%
dfw = df.loc[(df.experiment.isin(['e1', 'e3', 'e4','e5', 'e6'])) & (df.culture == 'Co_Culture')]

# %%
#dfw = df.loc[(df.experiment.isin(['e1','e3', 'e4','e5', 'e6'])) # & (df.culture == 'Co_Culture')
#            ]

# %%
train_df_orig, test_df_orig = cp.split_train_test(dfw,test_size=0.4)

# %%
train_df = cp.augment_training(train_df_orig)
test_df = cp.resample_df(test_df_orig, period='1d', dropna=False)

# %%
train_df.columns
# Out:
# Index(['experiment_sample', 'experiment', 'sample', 'PRO', 'ALT', 'culture',
#        'day', 'FL', 'augment_name', 'experiment_sample_orig'],
#       dtype='object')

# %%
(train_df.experiment_sample == train_df.experiment_sample_orig).sum()
# Out:
# 0

# %%
#train_df.loc[:, 'experiment_sample'] = train_df.experiment_sample + ', ' + train_df.augment_name

# %%
train_df = cp.update_calculated_fields(train_df, group_col='experiment_sample', min_fl=None, add_experiment_sample=False)
test_df = cp.update_calculated_fields(test_df, group_col='experiment_sample', min_fl=None, add_experiment_sample=False)
# Out:
# D:\Users\Osnat\Documents\GitHub\ccpa\CCPA_lib.py:85: RuntimeWarning: invalid value encountered in log
#   df.loc[:, 'logFL'] =np.log(df['FL'])

# %%
train_dfdecline = cp.generate_decline(train_df, scale=False)

# %%
train_dfdecline, train_dfcoef = cp.add_exponential(train_dfdecline)
# Out:
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# C:\Users\Osnat\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:214: RuntimeWarning: overflow encountered in square
#   z = (f / f_scale) ** 2
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# ...
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
test_dfdecline = cp.generate_decline(test_df, scale=False)

# %%
test_dfdecline, test_dfcoef = cp.add_exponential(test_dfdecline)

# %%
train_features_df = cp.generate_features(train_df)
test_features_df = cp.generate_features(test_df)
t = cp.update_calculated_fields(train_dfdecline, group_col='experiment_sample', min_fl=None, add_experiment_sample=False)
t.loc[:, 'experiment_sample'] = t.experiment_sample + ', ' + t.augment_name
train_features_dfdecline = cp.generate_features(t)
test_features_dfdecline = cp.generate_features(cp.update_calculated_fields(test_dfdecline, 
                                                                           group_col='experiment_sample', 
                                                                           min_fl=None, add_experiment_sample=False))

# %%
train_df = train_df.loc[train_df.day <= 120]
test_df = test_df.loc[test_df.day <= 120]
train_dfdecline = train_dfdecline.loc[train_dfdecline.day <= 80]
test_dfdecline = test_dfdecline.loc[test_dfdecline.day <= 80]

# %% [raw]
# ts_decline_metadf = cp.get_meta(dfdecline)
# ts_decline_metadf.index = ts_decline_metadf.experiment_sample
# _y= ts_decline_metadf.PRO + ','+ ts_decline_metadf.ALT
# ts_decline_features_df = tsfresh.extract_relevant_features(
#     dfdecline.loc[:, ['experiment_sample', 'day',
#        'exponential', 'decline', 'exponential_diff',
#        'decline_scaled'] ].fillna(0),
#     _y,
#      column_id='experiment_sample', column_kind=None,
#      column_sort='day',
#      #column_value=
#     )

# %% [markdown]
# # Compare Models

# %%
# compare models based on different experiment features
# value_col, 

value_col_list = ['FL', 'logFL']
#, 'zscoreFL', 'rateFL', 'ratelogFL']
decline_col_list = ['exponential', 'decline', 'exponential_diff', 'decline_scaled']
y_col_list = ['PRO', 'ALT', 'PRO_ALT', 'ALT_PRO']

# %%
repetitions=10

# %%
stats_list = []
y_list = []
clf_list = []
features_list = []

# %%
test_df.experiment_sample.value_counts()

# %%
res, _y_list, _clf_list, _features_list = cp.compare_models2(train_df, test_df, 
               value_col_list=value_col_list, 
               y_col_list=y_col_list, 
               repetitions=repetitions,
               return_y=True)
stats_list.extend(res)
y_list.extend(_y_list)
clf_list.extend(_clf_list)
features_list.extend(_features_list)

# %%
res, _y_list, _clf_list, _features_list = cp.compare_models2(train_dfdecline, test_dfdecline, 
               value_col_list=decline_col_list, 
               y_col_list=y_col_list, 
               repetitions=repetitions,
               return_y=True)
stats_list.extend(res)
y_list.extend(_y_list)
clf_list.extend(_clf_list)
features_list.extend(_features_list)

# %%
res, _y_list, _clf_list, _features_list = cp.compare_models2(train_features_df, test_features_df, 
               value_col_list=['features'], 
               y_col_list=y_col_list, 
               repetitions=repetitions,
               return_y=True, features_mode=True)
stats_list.extend(res)
y_list.extend(_y_list)
clf_list.extend(_clf_list)
features_list.extend(_features_list)

# %%
res, _y_list, _clf_list, _features_list = cp.compare_models2(train_features_dfdecline, test_features_dfdecline, 
               value_col_list=['decline_features'], 
               y_col_list=y_col_list, 
               repetitions=repetitions,
               return_y=True, features_mode=True)
stats_list.extend(res)
y_list.extend(_y_list)
clf_list.extend(_clf_list)
features_list.extend(_features_list)

# %% [raw]
# res, _y_list, _clf_list, _features_list = cp.compare_models_ts_features(df_exp_coef, ts_decline_metadf,
#                y_col_list=y_col_list, mode='_exponential_coef',
#                repetitions=repetitions,
#                return_y=True)
# stats_list.extend(res)
# y_list.extend(_y_list)
# clf_list.extend(_clf_list)
# features_list.extend(_features_list)

# %%
train_dfg = train_dfdecline.groupby('experiment_sample').apply(cp._calculate_exponential_diff_features).fillna(0)
test_dfg = test_dfdecline.groupby('experiment_sample').apply(cp._calculate_exponential_diff_features).fillna(0)
res, _y_list, _clf_list, _features_list = cp.compare_models2(train_features_dfdecline, test_features_dfdecline, 
               value_col_list=['exp_diff_features'], 
               y_col_list=y_col_list, 
               repetitions=repetitions,
               return_y=True, features_mode=True)
stats_list.extend(res)
y_list.extend(_y_list)
clf_list.extend(_clf_list)
features_list.extend(_features_list)

# %%
len(stats_list)

# %%
stats_df = pd.DataFrame.from_records(stats_list)

# %%
stats_df.describe()

# %%
stats_df.value_col.unique()

# %%
f, ax = plt.subplots(figsize=(10, 7))
sns.barplot(x="f1_test", y="model", data=stats_df.sort_values(by="f1_test").nlargest(columns="f1_test", n=20),
            hue='value_col')

# %%
f, ax = plt.subplots(figsize=(10, 7))
v='accuracy_test'
sns.barplot(x=v, y="model", data=stats_df.sort_values(by=v).nlargest(columns=v, n=20),
            hue='value_col')

# %% [markdown]
# # Pro comparison

# %%
order = stats_df.loc[(stats_df.y_col.isin(['PRO', 'PRO_ALT'])) & (stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[(stats_df.y_col.isin(['PRO', 'PRO_ALT'])) & (stats_df['cumsum'] == False)], 
            x='value_col', y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=6, kind='box',
            order=order,
           )

# %%
#order = stats_df.groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[stats_df.y_col.isin(['PRO', 'PRO_ALT']) ], 
            x='value_col', y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=6, kind='box',
            order=order,
            hue='cumsum'
           )

# %%
sns.catplot(data=stats_df.loc[stats_df.y_col.isin(['PRO', 'PRO_ALT']) & (stats_df['cumsum'] == False)], 
            x='value_col', y='f1_test', 
            hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=6, kind='point',
            order=order
           )

# %%
sns.catplot(data=stats_df.loc[stats_df.y_col.isin(['PRO', 'PRO_ALT']) & (stats_df['cumsum'] == False)], 
            x='value_col', y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            hue='y_col', 
            aspect=6, kind='box',
            order=order
           )

# %% [markdown]
# # ALT comparison

# %%
order = stats_df.loc[(stats_df.y_col.isin(['ALT', 'ALT_PRO'])) & (stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[(stats_df.y_col.isin(['ALT', 'ALT_PRO'])) & (stats_df['cumsum'] == False)], 
            x='value_col', y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=8, kind='box',
            order=order,
           )

# %%
#order = stats_df.groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[stats_df.y_col.isin(['ALT', 'ALT_PRO']) ], 
            x='value_col', y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=6, kind='box',
            order=order,
            hue='cumsum'
           )

# %%
sns.catplot(data=stats_df.loc[stats_df.y_col.isin(['ALT', 'ALT_PRO']) & (stats_df['cumsum'] == False)], 
            x='value_col', y='f1_test', 
            hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=6, kind='point',
            order=order
           )

# %%
stats_df.loc[:,['model', 'f1_test']].nlargest(columns=['f1_test'], n=15)

# %%
#order = stats_df.loc[(stats_df.y_col.isin(['ALT'])) & (stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[( #(stats_df.y_col.isin(['ALT'])) & 
                               (stats_df['cumsum'] == False) )], 
            x='y_col', 
            y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=5, kind='box',
            order=['PRO_ALT', 'PRO', 'ALT', 'ALT_PRO'],
           )

# %%
#order = stats_df.loc[(stats_df.y_col.isin(['ALT'])) & (stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[( #(stats_df.y_col.isin(['ALT'])) & 
                               (stats_df['cumsum'] == False) & 
                              (stats_df['value_col'] == 'decline'))], 
            x='y_col', 
            y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=5, kind='box',
            order=['PRO_ALT', 'PRO', 'ALT', 'ALT_PRO'],
           )

# %%
#order = stats_df.loc[(stats_df.y_col.isin(['ALT'])) & (stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[( #(stats_df.y_col.isin(['ALT'])) & 
                               (stats_df['cumsum'] == False) & 
                              (stats_df['value_col'] == 'decline'))], 
            x='y_col', 
            y='f1_test', 
            hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=5, kind='box',
            order=['PRO_ALT', 'PRO', 'ALT', 'ALT_PRO'],
           )

# %%
#order = stats_df.loc[(stats_df.y_col.isin(['ALT'])) & (stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[( #(stats_df.y_col.isin(['ALT'])) & 
                               (stats_df['cumsum'] == False) & 
                              (stats_df['value_col'] == 'exponential_diff'))], 
            x='y_col', 
            y='f1_test', 
            hue='resample_period', 
            #col='cumsum',
            #row='y_col', 
            aspect=5, kind='box',
            order=['PRO_ALT', 'PRO', 'ALT', 'ALT_PRO'],
           )

# %%
order = stats_df.loc[(stats_df['cumsum'] == False)].groupby('value_col').f1_test.mean().sort_values(ascending=False).index
sns.catplot(data=stats_df.loc[(stats_df['cumsum'] == False)], 
            x='value_col', y='f1_test', 
            #hue='resample_period', 
            #col='cumsum',
            hue='y_col', 
            aspect=6, kind='box',
            order=order,
            hue_order=['PRO_ALT', 'PRO', 'ALT', 'ALT_PRO'],
           )

# %%
ts_decline_features_df.shape, ts_features_df.shape

# %%
order

# %%
stats_df.columns

# %%
sns.relplot(data=stats_df, x='n_features', y='f1_test', height=10, hue='value_col')

# %%
sns.catplot(data=stats_df[stats_df.n_features < 100], y='n_features', hue='resample_period', #hue='f1_test', 
            aspect=8, x='value_col', kind='box')
